# %% [markdown]
# #### 1. 문제 정의 : 8.9 허프만 트리 생성 알고리즘

# %% [markdown]
# #### 2. 알고리즘 설명

# %% [markdown]
# #### 3. 손으로 푼 예제
# ![8.9_손으로푼예제.png](attachment:8.9_손으로푼예제.png)

# %% [markdown]
# #### 4. 알고리즘 개요(입력 변수, 출력, 알고리즘 개요)
# 함수명 : make_heap_tree(freq, label)
# 입 력   변 수 : 각 문자의 빈도수, 각 문자
# 출력 : 힙 트리 생성 과정에서의 중간 결과와 최종 힙 트리
# 함 수   설 명 : 우선 순위가 가장 높은 두 개으 ㅣ엔트리를 꺼낸 후 e1과 e2를 병합하여 다시 힙에 삽입한다. 이때 힙에 들어가는 엔트리는 (루르값의 합, 문자들의 합)이 된다. 최종적으로 힙에는 하나의 루투 노드만 남아 이를 출력한다.

# %% [markdown]
# #### 5. 알고리즘 코드

# %%
import heapq
def make_heap_tree(freq, label):
    n = len(freq)
    h = []
    for i in range(n):
        heapq.heappush(h, (freq[i], label[i]))

    for i in range(1, n):
        e1 = heapq.heappop(h)
        e2 = heapq.heappop(h)
        heapq.heappush(h, (e1[0]+e2[0], e1[1]+e2[1]))
        print(e1, "+", e2)

    print(heapq.heappop(h))

# %% [markdown]
# #### 6. 테스트 코드

# %%
import heapq
def make_heap_tree(freq, label):
    n = len(freq)
    h = []
    for i in range(n):
        heapq.heappush(h, (freq[i], label[i]))

    for i in range(1, n):
        e1 = heapq.heappop(h)
        e2 = heapq.heappop(h)
        heapq.heappush(h, (e1[0]+e2[0], e1[1]+e2[1]))
        print(e1, "+", e2)

    print(heapq.heappop(h))

label = [ 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
freq = [24, 3, 8, 10, 33, 6, 4, 12]
make_heap_tree(freq, label)

# %% [markdown]
# #### 7. 수행 결과
# ![8.9_실행결과.png](attachment:8.9_실행결과.png)

# %% [markdown]
# #### 8. 복잡도 분석
# 먼저 5~6행의 초기 우선순위 큐를 만드는 과정에서 루프는 n번 반복한다. 그 안에서 힙으로 구현된 우선순위 큐에서는 삽입과 삭제 연산의 복잡도가 모두 O(log2n) 이므로 5~6행의 복잡도는 O(nlog2n)이다.
# 8~11행의 루프도 n번 반복되며, 한 번의 반복에서 우선순위 큐의 두 번의 삭제 연산과 한 번의 삽입 연산이 사용되므로 이들의 복잡도 또한 O(log2n)이다.
#
# 따라서 허프만 알고리즘의 시간 복잡도는 O(nlog2n)이다.

# %% [markdown]
# #### 9. 조별 협력 내용
# ![8.9_조별협력내용.png](attachment:8.9_조별협력내용.png)
